# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
import json
import scipy.stats as st
from scipy.stats import linregress
import os
import csv
import datetime


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
lat_list = []
lng_list = []
hems = []
#countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        lat_list.append(lat_lng[0])
        lng_list.append(lat_lng[1])
        if lat_lng[0] >= 0:
            hems.append('N')
        else: hems.append('S')
        
# Print the city count to confirm sufficient count
len(cities)
#print(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
record_counter = 0
set_counter = 0

# Set up the url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6de60382309072d62105b9ef04643650&units=imperial&q=

# %%
#creating lists to store extracted values 
city_name = []
date = []
latitude = []
longitude = []
temp = []
humidity = []
cloudiness = []
wind = []
country = []
city_id = []

# %%
#Run the API call for each city
print("Beginning Data Retrieval ")
print("-----------------------------")

#dictionary
cities_dict = []
#creating loop
for city in cities:
    city_url = query_url + city
    # Get weather data
    #response = requests.get(city_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0
        
    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    
    try:
        response = requests.get(city_url).json()
        #print (response)
        cities_dict.append({"city_name": city, 
                           "date": response["dt"], 
                           "latitude": response["coord"]["lat"], 
                           "longitude": response["coord"]["lon"],
                           "temp": response["main"]["temp"],
                           "humidity": response["main"]["humidity"],
                           "cloudiness": response["clouds"]["all"],
                           "wind": response["wind"]["speed"],
                           #"Hemisphere": hems,
                           "country": response["sys"]["country"]})
        #print(city)
        
    except:     
        print("City not found!")
        
        pass
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')    
    
#print(cities_dict)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 0 | sindor
# Processing record 2 of set 0 | barrow
# Processing record 3 of set 0 | vila franca do campo
# Processing record 4 of set 0 | lagoa
# Processing record 5 of set 0 | kilindoni
# Processing record 6 of set 0 | geraldton
# Processing record 7 of set 0 | taolanaro
# City not found!
# Processing record 8 of set 0 | busselton
# Processing record 9 of set 0 | grand gaube
# Processing record 10 of set 0 | kapaa
# Processing record 11 of set 0 | qaanaaq
# Processing record 12 of set 0 | rikitea
# Processing record 13 of set 0 | estevan
# Processing record 14 of set 0 | atuona
# Processing record 15 of set 0 | avarua
# Processing record 16 of set 0 | ambon
# Processing record 17 of set 0 | yaan
# Processing record 18 of set 0 | cape town
# Processing record 19 of set 0 | east london
# Processing record 20 of set 0 | hamilton
# Processing record 21 of set 0 | yellowknife
# Processing record 22 of set 0 | sakaraha
# Processing record 23 of set 0 | souillac
# Processing record 24 of set 0 | chuy
# Processing record 25 of set 0 | saint george
# Processing record 26 of set 0 | ternate
# Processing record 27 of set 0 | lorengau
# Processing record 28 of set 0 | bengkulu
# Processing record 29 of set 0 | mandalgovi
# Processing record 30 of set 0 | nome
# Processing record 31 of set 0 | khatanga
# Processing record 32 of set 0 | victoria
# Processing record 33 of set 0 | vokhtoga
# Processing record 34 of set 0 | esperance
# Processing record 35 of set 0 | darhan
# Processing record 36 of set 0 | hermanus
# Processing record 37 of set 0 | tasiilaq
# Processing record 38 of set 0 | ukiah
# Processing record 39 of set 0 | faanui
# Processing record 40 of set 0 | aitape
# Processing record 41 of set 0 | terney
# Processing record 42 of set 0 | arraial do cabo
# Processing record 43 of set 0 | sorland
# Processing record 44 of set 0 | severnyy
# Processing record 45 of set 0 | airai
# Processing record 46 of set 0 | nikolskoye
# Processing record 47 of set 0 | albany
# Processing record 48 of set 0 | kloulklubed
# Processing record 49 of set 0 | caravelas
# Processing record 50 of set 0 | tokur
# Processing record 0 of set 1 | yar-sale
# Processing record 1 of set 1 | cordoba
# Processing record 2 of set 1 | norman wells
# Processing record 3 of set 1 | bredasdorp
# Processing record 4 of set 1 | kovdor
# Processing record 5 of set 1 | kruisfontein
# Processing record 6 of set 1 | vaini
# Processing record 7 of set 1 | kondoa
# Processing record 8 of set 1 | batticaloa
# Processing record 9 of set 1 | saint-philippe
# Processing record 10 of set 1 | provideniya
# Processing record 11 of set 1 | muroto
# Processing record 12 of set 1 | kilosa
# Processing record 13 of set 1 | butaritari
# Processing record 14 of set 1 | hilo
# Processing record 15 of set 1 | isabela
# Processing record 16 of set 1 | mar del plata
# Processing record 17 of set 1 | sedlcany
# Processing record 18 of set 1 | severo-kurilsk
# Processing record 19 of set 1 | bubaque
# Processing record 20 of set 1 | cabo san lucas
# Processing record 21 of set 1 | ponta do sol
# Processing record 22 of set 1 | batsfjord
# Processing record 23 of set 1 | jamestown
# Processing record 24 of set 1 | nicoya
# Processing record 25 of set 1 | dikson
# Processing record 26 of set 1 | murmansk
# Processing record 27 of set 1 | saleaula
# City not found!
# Processing record 28 of set 1 | omboue
# Processing record 29 of set 1 | mataura
# Processing record 30 of set 1 | lebu
# Processing record 31 of set 1 | attawapiskat
# City not found!
# Processing record 32 of set 1 | red bluff
# Processing record 33 of set 1 | ushuaia
# Processing record 34 of set 1 | ribeira grande
# Processing record 35 of set 1 | vestmannaeyjar
# Processing record 36 of set 1 | punta arenas
# Processing record 37 of set 1 | cherskiy
# Processing record 38 of set 1 | cidreira
# Processing record 39 of set 1 | new norfolk
# Processing record 40 of set 1 | carnarvon
# Processing record 41 of set 1 | nampa
# Processing record 42 of set 1 | pisco
# Processing record 43 of set 1 | samusu
# City not found!
# Processing record 44 of set 1 | tazovskiy
# Processing record 45 of set 1 | kungurtug
# Processing record 46 of set 1 | te anau
# Processing record 47 of set 1 | half moon bay
# Processing record 48 of set 1 | acapulco
# Processing record 49 of set 1 | husavik
# Processing record 50 of set 1 | kohlu
# Processing record 0 of set 2 | bargal
# City not found!
# Processing record 1 of set 2 | khasan
# Processing record 2 of set 2 | crib point
# Processing record 3 of set 2 | grindavik
# Processing record 4 of set 2 | tumannyy
# City not found!
# Processing record 5 of set 2 | belushya guba
# City not found!
# Processing record 6 of set 2 | uhlove
# Processing record 7 of set 2 | bilibino
# Processing record 8 of set 2 | yulara
# Processing record 9 of set 2 | tiksi
# Processing record 10 of set 2 | mount isa
# Processing record 11 of set 2 | sao filipe
# Processing record 12 of set 2 | tautira
# Processing record 13 of set 2 | bluff
# Processing record 14 of set 2 | sobolevo
# Processing record 15 of set 2 | songjianghe
# Processing record 16 of set 2 | ilave
# Processing record 17 of set 2 | awbari
# Processing record 18 of set 2 | quatre cocos
# Processing record 19 of set 2 | virginia beach
# Processing record 20 of set 2 | yambio
# Processing record 21 of set 2 | san patricio
# Processing record 22 of set 2 | saint anthony
# Processing record 23 of set 2 | san cristobal
# Processing record 24 of set 2 | illoqqortoormiut
# City not found!
# Processing record 25 of set 2 | kayes
# Processing record 26 of set 2 | saskylakh
# Processing record 27 of set 2 | talnakh
# Processing record 28 of set 2 | mahebourg
# Processing record 29 of set 2 | lipari
# Processing record 30 of set 2 | atar
# Processing record 31 of set 2 | guerrero negro
# Processing record 32 of set 2 | hami
# Processing record 33 of set 2 | port alfred
# Processing record 34 of set 2 | nizhneyansk
# City not found!
# Processing record 35 of set 2 | ihiala
# Processing record 36 of set 2 | barentsburg
# City not found!
# Processing record 37 of set 2 | san quintin
# Processing record 38 of set 2 | pochutla
# Processing record 39 of set 2 | maranding
# Processing record 40 of set 2 | upernavik
# Processing record 41 of set 2 | soltsy
# Processing record 42 of set 2 | nanga eboko
# Processing record 43 of set 2 | dong hoi
# Processing record 44 of set 2 | uribia
# Processing record 45 of set 2 | anori
# Processing record 46 of set 2 | georgetown
# Processing record 47 of set 2 | nikki
# Processing record 48 of set 2 | grand river south east
# City not found!
# Processing record 49 of set 2 | toronto
# Processing record 50 of set 2 | chokurdakh
# Processing record 0 of set 3 | soyo
# Processing record 1 of set 3 | praia da vitoria
# Processing record 2 of set 3 | kahului
# Processing record 3 of set 3 | ilulissat
# Processing record 4 of set 3 | manassas
# Processing record 5 of set 3 | maraa
# Processing record 6 of set 3 | verkhoyansk
# Processing record 7 of set 3 | leshukonskoye
# Processing record 8 of set 3 | castro
# Processing record 9 of set 3 | coahuayana
# Processing record 10 of set 3 | kavieng
# Processing record 11 of set 3 | salalah
# Processing record 12 of set 3 | kirensk
# Processing record 13 of set 3 | weinan
# Processing record 14 of set 3 | avera
# Processing record 15 of set 3 | sechura
# Processing record 16 of set 3 | minggang
# Processing record 17 of set 3 | lieksa
# Processing record 18 of set 3 | gharghoda
# Processing record 19 of set 3 | narsaq
# Processing record 20 of set 3 | goderich
# Processing record 21 of set 3 | joshimath
# Processing record 22 of set 3 | leningradskiy
# Processing record 23 of set 3 | hasaki
# Processing record 24 of set 3 | marawi
# Processing record 25 of set 3 | ostrovnoy
# Processing record 26 of set 3 | tromso
# Processing record 27 of set 3 | at-bashi
# Processing record 28 of set 3 | trinidad
# Processing record 29 of set 3 | mezhdurechensk
# Processing record 30 of set 3 | changji
# Processing record 31 of set 3 | nuuk
# Processing record 32 of set 3 | nantucket
# Processing record 33 of set 3 | urengoy
# Processing record 34 of set 3 | phan thiet
# Processing record 35 of set 3 | iracoubo
# Processing record 36 of set 3 | gbarnga
# Processing record 37 of set 3 | jilin
# Processing record 38 of set 3 | baykit
# Processing record 39 of set 3 | daru
# Processing record 40 of set 3 | luderitz
# Processing record 41 of set 3 | meulaboh
# Processing record 42 of set 3 | amderma
# City not found!
# Processing record 43 of set 3 | kuruman
# Processing record 44 of set 3 | lapua
# Processing record 45 of set 3 | tobol
# Processing record 46 of set 3 | sur
# Processing record 47 of set 3 | codrington
# Processing record 48 of set 3 | evensk
# Processing record 49 of set 3 | jalu
# Processing record 50 of set 3 | keti bandar
# Processing record 0 of set 4 | saint-pierre
# Processing record 1 of set 4 | faridan
# City not found!
# Processing record 2 of set 4 | mackay
# Processing record 3 of set 4 | kumluca
# Processing record 4 of set 4 | nyaunglebin
# Processing record 5 of set 4 | broken hill
# Processing record 6 of set 4 | pamplona
# Processing record 7 of set 4 | port blair
# Processing record 8 of set 4 | broome
# Processing record 9 of set 4 | bethel
# Processing record 10 of set 4 | lasa
# Processing record 11 of set 4 | sabang
# Processing record 12 of set 4 | sentyabrskiy
# City not found!
# Processing record 13 of set 4 | amapa
# Processing record 14 of set 4 | hobart
# Processing record 15 of set 4 | velsk
# Processing record 16 of set 4 | pevek
# Processing record 17 of set 4 | capaccio
# Processing record 18 of set 4 | arkhangelsk
# Processing record 19 of set 4 | alofi
# Processing record 20 of set 4 | college
# Processing record 21 of set 4 | anloga
# Processing record 22 of set 4 | sitka
# Processing record 23 of set 4 | nishihara
# Processing record 24 of set 4 | komsomolskiy
# Processing record 25 of set 4 | zabol
# Processing record 26 of set 4 | llandrindod wells
# Processing record 27 of set 4 | coquimbo
# Processing record 28 of set 4 | trelew
# Processing record 29 of set 4 | touros
# Processing record 30 of set 4 | caucaia
# Processing record 31 of set 4 | fairbanks
# Processing record 32 of set 4 | parabel
# Processing record 33 of set 4 | puerto ayora
# Processing record 34 of set 4 | vardo
# Processing record 35 of set 4 | erenhot
# Processing record 36 of set 4 | camacha
# Processing record 37 of set 4 | cayenne
# Processing record 38 of set 4 | adrar
# Processing record 39 of set 4 | isangel
# Processing record 40 of set 4 | santo nino
# Processing record 41 of set 4 | san jeronimo
# Processing record 42 of set 4 | khandyga
# Processing record 43 of set 4 | lianzhou
# Processing record 44 of set 4 | abashiri
# Processing record 45 of set 4 | hambantota
# Processing record 46 of set 4 | bathsheba
# Processing record 47 of set 4 | kodiak
# Processing record 48 of set 4 | ko samui
# Processing record 49 of set 4 | los llanos de aridane
# Processing record 50 of set 4 | provost
# Processing record 0 of set 5 | port elizabeth
# Processing record 1 of set 5 | medicine hat
# Processing record 2 of set 5 | tessalit
# Processing record 3 of set 5 | kribi
# Processing record 4 of set 5 | mizpe ramon
# City not found!
# Processing record 5 of set 5 | sheboygan
# Processing record 6 of set 5 | padang
# Processing record 7 of set 5 | los cedrales
# Processing record 8 of set 5 | serenje
# Processing record 9 of set 5 | makat
# Processing record 10 of set 5 | buala
# Processing record 11 of set 5 | port-cartier
# Processing record 12 of set 5 | thompson
# Processing record 13 of set 5 | along
# Processing record 14 of set 5 | neepawa
# Processing record 15 of set 5 | hithadhoo
# Processing record 16 of set 5 | shingu
# Processing record 17 of set 5 | palabuhanratu
# City not found!
# Processing record 18 of set 5 | rungata
# City not found!
# Processing record 19 of set 5 | great yarmouth
# Processing record 20 of set 5 | torbay
# Processing record 21 of set 5 | russell
# Processing record 22 of set 5 | cockburn town
# Processing record 23 of set 5 | zhigansk
# Processing record 24 of set 5 | duldurga
# Processing record 25 of set 5 | ajaccio
# Processing record 26 of set 5 | asosa
# Processing record 27 of set 5 | nizhnyaya poyma
# Processing record 28 of set 5 | richards bay
# Processing record 29 of set 5 | saldanha
# Processing record 30 of set 5 | palu
# Processing record 31 of set 5 | bambous virieux
# Processing record 32 of set 5 | port augusta
# Processing record 33 of set 5 | clyde river
# Processing record 34 of set 5 | itarema
# Processing record 35 of set 5 | kenai
# Processing record 36 of set 5 | hellvik
# Processing record 37 of set 5 | cravo norte
# Processing record 38 of set 5 | tuktoyaktuk
# Processing record 39 of set 5 | ayan
# Processing record 40 of set 5 | longyearbyen
# Processing record 41 of set 5 | mendez
# Processing record 42 of set 5 | cocobeach
# Processing record 43 of set 5 | kavaratti
# Processing record 44 of set 5 | prince george
# Processing record 45 of set 5 | necochea
# Processing record 46 of set 5 | bayan
# Processing record 47 of set 5 | umm kaddadah
# Processing record 48 of set 5 | bandarbeyla
# Processing record 49 of set 5 | andarab
# City not found!
# Processing record 50 of set 5 | povenets
# Processing record 0 of set 6 | flinders
# Processing record 1 of set 6 | sept-iles
# Processing record 2 of set 6 | peace river
# Processing record 3 of set 6 | madera
# Processing record 4 of set 6 | tezu
# Processing record 5 of set 6 | poletayevo
# Processing record 6 of set 6 | jiayuguan
# Processing record 7 of set 6 | northam
# Processing record 8 of set 6 | oyama
# Processing record 9 of set 6 | sao joao da barra
# Processing record 10 of set 6 | tam ky
# Processing record 11 of set 6 | tura
# Processing record 12 of set 6 | sanming
# Processing record 13 of set 6 | salina cruz
# Processing record 14 of set 6 | tevriz
# Processing record 15 of set 6 | kalamazoo
# Processing record 16 of set 6 | afsin
# Processing record 17 of set 6 | bandar-e anzali
# Processing record 18 of set 6 | disa
# Processing record 19 of set 6 | ligayan
# Processing record 20 of set 6 | tuatapere
# Processing record 21 of set 6 | west wendover
# Processing record 22 of set 6 | yerbogachen
# Processing record 23 of set 6 | bud
# Processing record 24 of set 6 | korcula
# Processing record 25 of set 6 | chabahar
# Processing record 26 of set 6 | hofn
# Processing record 27 of set 6 | epinal
# Processing record 28 of set 6 | eirunepe
# Processing record 29 of set 6 | aksarka
# Processing record 30 of set 6 | carballo
# Processing record 31 of set 6 | longlac
# City not found!
# Processing record 32 of set 6 | vylkove
# Processing record 33 of set 6 | solovetskiy
# City not found!
# Processing record 34 of set 6 | north bend
# Processing record 35 of set 6 | srikakulam
# Processing record 36 of set 6 | novobureyskiy
# Processing record 37 of set 6 | kautokeino
# Processing record 38 of set 6 | tucurui
# Processing record 39 of set 6 | aleppo
# Processing record 40 of set 6 | usogorsk
# Processing record 41 of set 6 | namatanai
# Processing record 42 of set 6 | ust-nera
# Processing record 43 of set 6 | molina
# Processing record 44 of set 6 | chara
# Processing record 45 of set 6 | vizinga
# Processing record 46 of set 6 | kamenskoye
# City not found!
# Processing record 47 of set 6 | prince rupert
# Processing record 48 of set 6 | kensington
# Processing record 49 of set 6 | uyutne
# Processing record 50 of set 6 | korla
# Processing record 0 of set 7 | vaitupu
# City not found!
# Processing record 1 of set 7 | starokozache
# Processing record 2 of set 7 | havre-saint-pierre
# Processing record 3 of set 7 | bitung
# Processing record 4 of set 7 | yanan
# City not found!
# Processing record 5 of set 7 | bonavista
# Processing record 6 of set 7 | gobabis
# Processing record 7 of set 7 | raudeberg
# Processing record 8 of set 7 | san javier
# Processing record 9 of set 7 | corowa
# Processing record 10 of set 7 | ouesso
# Processing record 11 of set 7 | zacualpan
# Processing record 12 of set 7 | ambanja
# Processing record 13 of set 7 | luena
# Processing record 14 of set 7 | hirara
# Processing record 15 of set 7 | bhavnagar
# Processing record 16 of set 7 | kangaatsiaq
# Processing record 17 of set 7 | hovd
# Processing record 18 of set 7 | filingue
# Processing record 19 of set 7 | tuggurt
# City not found!
# Processing record 20 of set 7 | ust-tsilma
# Processing record 21 of set 7 | mangai
# Processing record 22 of set 7 | kieta
# Processing record 23 of set 7 | kokopo
# Processing record 24 of set 7 | krasnorechenskiy
# Processing record 25 of set 7 | insar
# Processing record 26 of set 7 | mys shmidta
# City not found!
# Processing record 27 of set 7 | naze
# Processing record 28 of set 7 | bolungarvik
# City not found!
# Processing record 29 of set 7 | faya
# Processing record 30 of set 7 | greeley
# Processing record 31 of set 7 | kaitangata
# Processing record 32 of set 7 | ondorhaan
# City not found!
# Processing record 33 of set 7 | artyk
# City not found!
# Processing record 34 of set 7 | kununurra
# Processing record 35 of set 7 | gazimurskiy zavod
# Processing record 36 of set 7 | fort frances
# Processing record 37 of set 7 | jahrom
# City not found!
# Processing record 38 of set 7 | sioux lookout
# Processing record 39 of set 7 | dothan
# Processing record 40 of set 7 | jaciara
# Processing record 41 of set 7 | palmer
# Processing record 42 of set 7 | wahran
# City not found!
# Processing record 43 of set 7 | bethanien
# Processing record 44 of set 7 | batagay
# Processing record 45 of set 7 | makakilo city
# Processing record 46 of set 7 | belmonte
# Processing record 47 of set 7 | halifax
# Processing record 48 of set 7 | oriximina
# Processing record 49 of set 7 | borama
# City not found!
# Processing record 50 of set 7 | ornskoldsvik
# Processing record 0 of set 8 | la ronge
# Processing record 1 of set 8 | bowmore
# Processing record 2 of set 8 | atambua
# Processing record 3 of set 8 | kambar
# Processing record 4 of set 8 | srednekolymsk
# Processing record 5 of set 8 | anju
# Processing record 6 of set 8 | natal
# Processing record 7 of set 8 | emporia
# Processing record 8 of set 8 | berlevag
# Processing record 9 of set 8 | nosy varika
# Processing record 10 of set 8 | progreso
# Processing record 11 of set 8 | pozo colorado
# Processing record 12 of set 8 | boca do acre
# Processing record 13 of set 8 | ugoofaaru
# Processing record 14 of set 8 | safwah
# City not found!
# Processing record 15 of set 8 | marfino
# Processing record 16 of set 8 | beringovskiy
# Processing record 17 of set 8 | poum
# Processing record 18 of set 8 | ocampo
# Processing record 19 of set 8 | oxford
# Processing record 20 of set 8 | brookhaven
# Processing record 21 of set 8 | labuhan
# Processing record 22 of set 8 | ulladulla
# Processing record 23 of set 8 | tahe
# Processing record 24 of set 8 | gat
# Processing record 25 of set 8 | reyes
# Processing record 26 of set 8 | paine
# Processing record 27 of set 8 | gushikawa
# Processing record 28 of set 8 | shelburne
# Processing record 29 of set 8 | senneterre
# Processing record 30 of set 8 | sambava
# Processing record 31 of set 8 | biltine
# Processing record 32 of set 8 | maple creek
# Processing record 33 of set 8 | umm lajj
# Processing record 34 of set 8 | marcona
# City not found!
# Processing record 35 of set 8 | nioro
# Processing record 36 of set 8 | mazamari
# Processing record 37 of set 8 | pangody
# Processing record 38 of set 8 | umzimvubu
# City not found!
# Processing record 39 of set 8 | yurimaguas
# Processing record 40 of set 8 | hirado
# Processing record 41 of set 8 | louisbourg
# City not found!
# Processing record 42 of set 8 | zelenogorsk
# Processing record 43 of set 8 | partenit
# Processing record 44 of set 8 | tabou
# Processing record 45 of set 8 | assiniboia
# Processing record 46 of set 8 | islamnagar
# Processing record 47 of set 8 | luanda
# Processing record 48 of set 8 | chagda
# City not found!
# Processing record 49 of set 8 | vetluga
# Processing record 50 of set 8 | kananga
# Processing record 0 of set 9 | dalen
# Processing record 1 of set 9 | katsuura
# Processing record 2 of set 9 | iringa
# Processing record 3 of set 9 | kidodi
# Processing record 4 of set 9 | huron
# Processing record 5 of set 9 | ilorin
# Processing record 6 of set 9 | pacific grove
# Processing record 7 of set 9 | ixtapa
# Processing record 8 of set 9 | swindon
# Processing record 9 of set 9 | lavrentiya
# Processing record 10 of set 9 | kosmynino
# Processing record 11 of set 9 | san jose de sisa
# Processing record 12 of set 9 | turukhansk
# Processing record 13 of set 9 | karauzyak
# City not found!
# Processing record 14 of set 9 | karaul
# City not found!
# Processing record 15 of set 9 | harrisburg
# Processing record 16 of set 9 | si racha
# Processing record 17 of set 9 | mayskiy
# Processing record 18 of set 9 | rongcheng
# Processing record 19 of set 9 | nacala
# Processing record 20 of set 9 | haines junction
# Processing record 21 of set 9 | zhezkazgan
# Processing record 22 of set 9 | skibbereen
# Processing record 23 of set 9 | finote selam
# Processing record 24 of set 9 | kidal
# Processing record 25 of set 9 | boguchany
# Processing record 26 of set 9 | kirkwall
# Processing record 27 of set 9 | kayerkan
# Processing record 28 of set 9 | denpasar
# Processing record 29 of set 9 | sovetskaya gavan
# Processing record 30 of set 9 | haibowan
# City not found!
# Processing record 31 of set 9 | simoes
# Processing record 32 of set 9 | amahai
# Processing record 33 of set 9 | buraydah
# Processing record 34 of set 9 | weyburn
# Processing record 35 of set 9 | brae
# Processing record 36 of set 9 | manzanillo
# Processing record 37 of set 9 | sola
# Processing record 38 of set 9 | vila velha
# Processing record 39 of set 9 | ziyang
# Processing record 40 of set 9 | nguiu
# City not found!
# Processing record 41 of set 9 | marathon
# Processing record 42 of set 9 | salinas
# Processing record 43 of set 9 | novobirilyussy
# Processing record 44 of set 9 | bako
# Processing record 45 of set 9 | farafangana
# Processing record 46 of set 9 | chlorakas
# Processing record 47 of set 9 | nassjo
# Processing record 48 of set 9 | sinnamary
# Processing record 49 of set 9 | arlit
# Processing record 50 of set 9 | rondonopolis
# Processing record 0 of set 10 | berja
# Processing record 1 of set 10 | ancud
# Processing record 2 of set 10 | sal rei
# Processing record 3 of set 10 | olinda
# Processing record 4 of set 10 | egvekinot
# Processing record 5 of set 10 | vazhiny
# Processing record 6 of set 10 | chernyshevskiy
# Processing record 7 of set 10 | lengshuijiang
# Processing record 8 of set 10 | flin flon
# Processing record 9 of set 10 | bocana de paiwas
# Processing record 10 of set 10 | muisne
# Processing record 11 of set 10 | monrovia
# Processing record 12 of set 10 | anjozorobe
# Processing record 13 of set 10 | pokhara
# Processing record 14 of set 10 | prado
# Processing record 15 of set 10 | gaillac
# Processing record 16 of set 10 | mamou
# Processing record 17 of set 10 | saint-francois
# Processing record 18 of set 10 | gayny
# Processing record 19 of set 10 | andapa
# Processing record 20 of set 10 | desna
# Processing record 21 of set 10 | urucui
# Processing record 22 of set 10 | bom sucesso
# Processing record 23 of set 10 | potosi
# Processing record 24 of set 10 | qinzhou
# Processing record 25 of set 10 | arrifes
# Processing record 26 of set 10 | batagay-alyta
# Processing record 27 of set 10 | dakoro
# Processing record 28 of set 10 | wulanhaote
# City not found!
# Processing record 29 of set 10 | colorado
# Processing record 30 of set 10 | grand-santi
# Processing record 31 of set 10 | razole
# Processing record 32 of set 10 | vydrino
# Processing record 33 of set 10 | san lorenzo
# Processing record 34 of set 10 | dunedin
# Processing record 35 of set 10 | upata
# Processing record 36 of set 10 | santa isabel
# Processing record 37 of set 10 | clarence town
# Processing record 38 of set 10 | suicheng
# Processing record 39 of set 10 | marzuq
# Processing record 40 of set 10 | talcahuano
# Processing record 41 of set 10 | kirakira
# Processing record 42 of set 10 | kropotkin
# Processing record 43 of set 10 | mount gambier
# Processing record 44 of set 10 | coos bay
# Processing record 45 of set 10 | bagotville
# Processing record 46 of set 10 | santa lucia
# Processing record 47 of set 10 | naantali
# Processing record 48 of set 10 | port hardy
# Processing record 49 of set 10 | tabiauea
# City not found!
# Processing record 50 of set 10 | emiliano zapata
# Processing record 0 of set 11 | rubio
# Processing record 1 of set 11 | constitucion
# Processing record 2 of set 11 | ishurdi
# Processing record 3 of set 11 | kosh-agach
# Processing record 4 of set 11 | vuktyl
# Processing record 5 of set 11 | moissala
# Processing record 6 of set 11 | matamba
# Processing record 7 of set 11 | finschhafen
# Processing record 8 of set 11 | cheuskiny
# City not found!
# Processing record 9 of set 11 | yarada
# Processing record 10 of set 11 | meiktila
# Processing record 11 of set 11 | bahir dar
# Processing record 12 of set 11 | manaure
# Processing record 13 of set 11 | requena
# Processing record 14 of set 11 | pitimbu
# Processing record 15 of set 11 | ishigaki
# Processing record 16 of set 11 | wajima
# Processing record 17 of set 11 | sistranda
# Processing record 18 of set 11 | abu samrah
# Processing record 19 of set 11 | oistins
# Processing record 20 of set 11 | ajdabiya
# Processing record 21 of set 11 | upington
# Processing record 22 of set 11 | hailar
# Processing record 23 of set 11 | qasigiannguit
# Processing record 24 of set 11 | henties bay
# Processing record 25 of set 11 | pangnirtung
# Processing record 26 of set 11 | mengcheng
# Processing record 27 of set 11 | dortyol
# Processing record 28 of set 11 | negombo
# Processing record 29 of set 11 | kushima
# Processing record 30 of set 11 | nemuro
# Processing record 31 of set 11 | marshalltown
# Processing record 32 of set 11 | moree
# Processing record 33 of set 11 | sokoto
# Processing record 34 of set 11 | havelock
# Processing record 35 of set 11 | kurchum
# Processing record 36 of set 11 | petatlan
# Processing record 37 of set 11 | yeletskiy
# City not found!
# Processing record 38 of set 11 | poronaysk
# Processing record 39 of set 11 | sosnovo-ozerskoye
# Processing record 40 of set 11 | margate
# Processing record 41 of set 11 | zhanakorgan
# Processing record 42 of set 11 | punta cardon
# Processing record 43 of set 11 | yeppoon
# Processing record 44 of set 11 | chimore
# Processing record 45 of set 11 | san juan
# Processing record 46 of set 11 | ikalamavony
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Use the dictionary to create a dataframe named weather_data
weather_data = pd.DataFrame(cities_dict)
weather_data.count()
# Out:
# city_name     563
# date          563
# latitude      563
# longitude     563
# temp          563
# humidity      563
# cloudiness    563
# wind          563
# country       563
# dtype: int64

# %%
weather_data
# Out:
#                 city_name        date  latitude  longitude   temp  humidity  \
# 0                  sindor  1600658417     62.86      51.89  32.22        98
# 1                  barrow  1600658195     71.29    -156.79  33.80        69
# 2    vila franca do campo  1600658223     37.72     -25.43  66.20        82
# 3                   lagoa  1600658191     39.05     -27.98  66.45        76
# 4               kilindoni  1600658418     -7.91      39.67  76.19        76
# ..                    ...         ...       ...        ...    ...       ...
# 558          punta cardon  1600658300     11.66     -70.22  84.11        77
# 559               yeppoon  1600658578    -23.13     150.73  87.80        40
# 560               chimore  1600658578    -16.98     -65.13  74.62        70
# 561              san juan  1600658330    -31.54     -68.54  57.97        33
# 562           ikalamavony  1600658578    -21.15      46.58  54.32        74
#
#      cloudiness   wind country
# 0            84   6.69      RU
# 1            90  12.75      US
# 2            75  12.75      PT
# 3           100  17.47      PT
# 4            24   9.15      TZ
# ..          ...    ...     ...
# 558          75  18.70      VE
# 559           0   9.17      AU
# 560          70   2.37      BO
# 561           0   7.85      AR
# 562           0   4.81      MG
#
# [563 rows x 9 columns]

# %%
cities_list = zip(city,cloudiness,country,date,humidity,temp,latitude,longitude)
# Set variable for output file
output_file = os.path.join('output_data', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)
#weather_data.head(50)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['date'][0])
    ).strftime('%m/%d/%Y')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Latitude Vs Temperature Plot

plt.scatter(weather_data["latitude"],weather_data["temp"],edgecolors="black",facecolors="red")
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["latitude"],weather_data["humidity"],edgecolors="black",facecolors="green")
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsHumidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Latitude Vs Cloudiness

plt.scatter(weather_data["latitude"],weather_data["cloudiness"],edgecolors="black",facecolors="orange")
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Latitude Vs Wind Speed

plt.scatter(weather_data["latitude"],weather_data["wind"],edgecolors="black",facecolors="steelblue")
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../Images/LatitudeVsWindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
